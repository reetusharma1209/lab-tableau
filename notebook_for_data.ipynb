# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/we_fn_use_c_marketing_customer_value_analysis.csv')

# %%
df.shape
# Out:
# (9134, 24)

# %%
df.sample(5)
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 5021  GO94903      Oregon              4770.550911      Yes     Basic
# 2831  AK90865      Oregon              8207.858272       No     Basic
# 8067  WM36886  California              5757.442258      Yes     Basic
# 5774  ZF58696  California             13104.149110       No  Extended
# 8580  EP64069  California              5138.244998       No     Basic
#
#                  Education Effective To Date EmploymentStatus Gender  Income  \
# 5021               College            2/1/11    Medical Leave      F   12964
# 2831  High School or Below           2/22/11       Unemployed      F       0
# 8067                Master           1/31/11         Employed      M   88997
# 5774  High School or Below            2/7/11       Unemployed      M       0
# 8580              Bachelor            1/8/11         Employed      F   72264
#
#       ... Months Since Policy Inception Number of Open Complaints  \
# 5021  ...                            37                         0
# 2831  ...                            17                         0
# 8067  ...                            71                         0
# 5774  ...                            31                         0
# 8580  ...                            66                         0
#
#       Number of Policies     Policy Type        Policy  Renew Offer Type  \
# 5021                   4   Personal Auto   Personal L3            Offer1
# 2831                   5    Special Auto    Special L2            Offer2
# 8067                   3  Corporate Auto  Corporate L2            Offer2
# 5774                   2   Personal Auto   Personal L3            Offer1
# 8580                   9  Corporate Auto  Corporate L3            Offer3
#
#       Sales Channel Total Claim Amount  Vehicle Class Vehicle Size
# 5021            Web         362.774545   Two-Door Car      Medsize
# 2831          Agent         686.908270     Sports Car      Medsize
# 8067         Branch         174.041566  Four-Door Car        Small
# 5774          Agent        1430.548077     Sports Car      Medsize
# 8580            Web         272.649844  Four-Door Car      Medsize
#
# [5 rows x 24 columns]

# %%
df.to_csv(r'D:\ironhack\data_tableau.csv', index=False)
